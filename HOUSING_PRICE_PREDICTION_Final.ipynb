# %% [markdown]
# ![dab1435065514_444_126864066.jpg](attachment:dab1435065514_444_126864066.jpg)

# %% [markdown]
# # Aim: HOUSING PRICE PREDICTION

# %% [markdown]
# ### Problem Statement:
# Houses are one of the necessary need of each and every person around the globe and therefore housing and real estate market is one of the markets which is one of the major contributors in the world’s economy. It is a very large market and there are various companies working in the domain. Data science comes as a very important tool to solve problems in the domain to help the companies increase their overall revenue, profits, improving their marketing strategies and focusing on changing trends in house sales and purchases. Predictive modelling, Market mix modelling, recommendation systems are some of the machine learning techniques used for achieving the business goals for housing companies. Our problem is related to one such housing company.
# A US-based housing company named Surprise Housing has decided to enter the Australian market. The company uses data analytics to purchase houses at a price below their actual values and flip them at a higher price. For the same purpose, the company has collected a data set from the sale of houses in Australia. The data is provided in the CSV file below.
# The company is looking at prospective properties to buy houses to enter the market. You are required to build a model using Machine Learning in order to predict the actual value of the prospective properties and decide whether to invest in them or not. For this company wants to know:
# • Which variables are important to predict the price of variable?
# • How do these variables describe the price of the house?

# %% [markdown]
# ### Business Goal:
# You are required to model the price of houses with the available independent variables. This model will then be used by the management to understand how exactly the prices vary with the variables. They can accordingly manipulate the strategy of the firm and concentrate on areas that will yield high returns. Further, the model will be a good way for the management to understand the pricing dynamics of a new market.

# %% [markdown]
# ### Data fields

# %% [markdown]
# SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict
# MSSubClass: The building class
# MSZoning: The general zoning classification
# LotFrontage: Linear feet of street connected to property
# LotArea: Lot size in square feet
# Street: Type of road access
# Alley: Type of alley access
# LotShape: General shape of property
# LandContour: Flatness of the property
# Utilities: Type of utilities available
# LotConfig: Lot configuration
# LandSlope: Slope of property
# Neighborhood: Physical locations within Ames city limits
# Condition1: Proximity to main road or railroad
# Condition2: Proximity to main road or railroad (if a second is present)
# BldgType: Type of dwelling
# HouseStyle: Style of dwelling
# OverallQual: Overall material and finish quality
# OverallCond: Overall condition rating
# YearBuilt: Original construction date
# YearRemodAdd: Remodel date
# RoofStyle: Type of roof
# RoofMatl: Roof material
# Exterior1st: Exterior covering on house
# Exterior2nd: Exterior covering on house (if more than one material)
# MasVnrType: Masonry veneer type
# MasVnrArea: Masonry veneer area in square feet
# ExterQual: Exterior material quality
# ExterCond: Present condition of the material on the exterior
# Foundation: Type of foundation
# BsmtQual: Height of the basement
# BsmtCond: General condition of the basement
# BsmtExposure: Walkout or garden level basement walls
# BsmtFinType1: Quality of basement finished area
# BsmtFinSF1: Type 1 finished square feet
# BsmtFinType2: Quality of second finished area (if present)
# BsmtFinSF2: Type 2 finished square feet
# BsmtUnfSF: Unfinished square feet of basement area
# TotalBsmtSF: Total square feet of basement area
# Heating: Type of heating
# HeatingQC: Heating quality and condition
# CentralAir: Central air conditioning
# Electrical: Electrical system
# 1stFlrSF: First Floor square feet
# 2ndFlrSF: Second floor square feet
# LowQualFinSF: Low quality finished square feet (all floors)
# GrLivArea: Above grade (ground) living area square feet
# BsmtFullBath: Basement full bathrooms
# BsmtHalfBath: Basement half bathrooms
# FullBath: Full bathrooms above grade
# HalfBath: Half baths above grade
# Bedroom: Number of bedrooms above basement level
# Kitchen: Number of kitchens
# KitchenQual: Kitchen quality
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# Functional: Home functionality rating
# Fireplaces: Number of fireplaces
# FireplaceQu: Fireplace quality
# GarageType: Garage location
# GarageYrBlt: Year garage was built
# GarageFinish: Interior finish of the garage
# GarageCars: Size of garage in car capacity
# GarageArea: Size of garage in square feet
# GarageQual: Garage quality
# GarageCond: Garage condition
# PavedDrive: Paved driveway
# WoodDeckSF: Wood deck area in square feet
# OpenPorchSF: Open porch area in square feet
# EnclosedPorch: Enclosed porch area in square feet
# 3SsnPorch: Three season porch area in square feet
# ScreenPorch: Screen porch area in square feet
# PoolArea: Pool area in square feet
# PoolQC: Pool quality
# Fence: Fence quality
# MiscFeature: Miscellaneous feature not covered in other categories
# MiscVal: $Value of miscellaneous feature
# MoSold: Month Sold
# YrSold: Year Sold
# SaleType: Type of sale
# SaleCondition: Condition of sale

# %%
# importing all the required library 
import pandas as pd 
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Loading The Data

# %%
train=pd.read_csv(r'D:\python\Project-Housing_splitted\train.csv')
test=pd.read_csv(r'D:\python\Project-Housing_splitted\test.csv')

# %%
pd.set_option('display.max_columns',None)

# %%
train.sample(5) # Checking any 5 sample of the train data
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 744   68          20       RL         72.0    10665   Pave   NaN      IR1
# 966  986         190       RL         68.0    10880   Pave   NaN      Reg
# 625  301         190       RL         90.0    15750   Pave   NaN      Reg
# 406  579         160       FV         34.0     3604   Pave  Pave      Reg
# 313  742          20       RL         65.0     6768   Pave   NaN      IR1
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 744         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 966         Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 625         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 406         Lvl    AllPub    Corner       Gtl      Somerst       Norm
# 313         Lvl    AllPub    Inside       Gtl       Sawyer      Feedr
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test.sample(5)  # checkign 5 Sample of test data
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 227  1280          50  C (all)         60.0     7500   Pave   NaN      Reg
# 259  1221          20       RL         66.0     7800   Pave   NaN      IR1
# 214  1258          30       RL         56.0     4060   Pave   NaN      Reg
# 218    90          20       RL         60.0     8070   Pave   NaN      Reg
# 243  1145         190       RL         60.0    12180   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 227         Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 259         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 214         Lvl    AllPub    Corner       Gtl      Edwards      Feedr
# 218         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 243         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train.shape  #Shape of the training data
# Out:
# (1168, 81)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
# ...

# %% [markdown]
# ##### Train data :
# Data is having 1168 Rows and 81 columns.
# It is having 3 float, 35 intiger and 43 object values.
# We can see non-null valus are not equal in all columns, means data having null values. lets check null values.

# %%
pd.set_option('display.max_rows',None)

# %%
train.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       214
# LotArea             0
# Street              0
# Alley            1091
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          7
# MasVnrArea          7
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           30
# BsmtCond           30
# BsmtExposure       31
# BsmtFinType1       30
# BsmtFinSF1          0
# BsmtFinType2       31
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# ## EDA

# %%
missing=train.isnull().sum()
missing= missing[missing>0]
missing.sort_values(inplace= True)
plt.figure(figsize=(10,7))
missing.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see 18 columns are having Null values, Lets check the percentage of null values.

# %%
train['SalePrice'].describe()
# Out:
# count      1168.000000
# mean     181477.005993
# std       79105.586863
# min       34900.000000
# 25%      130375.000000
# 50%      163995.000000
# 75%      215000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
plt.figure(figsize=(7,7))
train['SalePrice'].plot.box()
plt.grid(True)

# %% [markdown]
# We can see minumum price for House is 34900 and maximum price is 755000,
# Diffrence in price are very high, we can say data is having outliers.
# 75 percentile of the house are below 215000

# %%
# Lets analyse target column 
plt.figure(figsize=(14,8))
sns.distplot(train['SalePrice'],color='darkgreen',kde_kws={"color": "k", "lw": 2.5, "label": "KDE"})
plt.xlabel('Sales Price', fontsize = 15)
plt.ylabel('Density', fontsize = 15)
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# From  the above graph we can see data is normaly distributed having positive skewnes.

# %% [markdown]
# #### Let's devide the data in to Numerial Feature and Categorical Feature

# %%
# lets divide the train data into categorical and numrical columns
cat_feature= train.select_dtypes(include=[np.object])

# lets divide the train data into categorical and numrical columns
num_feature= train.select_dtypes(include=[np.number])


# Dividing the test data into categorical and numerical data
cat_test= test.select_dtypes(include=[np.object])

num_test= test.select_dtypes(include=[np.number])

# %% [markdown]
# #### Temporal Variables(Eg: Datetime Variables)

# %% [markdown]
# From the Dataset we have 4 year variables. We have to  extract information from the datetime variables like no of years or no of days.

# %%
# list of variables that contain year information
year_feature = [feature for feature in num_feature if 'Yr' in feature or 'Year' in feature]

year_feature
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# let's explore the content of these year variables
for feature in year_feature:
    print(feature, train[feature].unique())
# Out:
# YearBuilt [1976 1970 1996 1977 2006 1957 1965 1947 1937 2003 1960 1955 1923 1930
#  2007 2001 1972 1950 1961 1953 1918 2010 1922 1934 2005 1946 1941 1948
#  1975 1978 1956 2004 1982 2000 2002 1920 1992 1936 1967 1989 1929 1968
#  1959 1935 1966 1931 1916 1998 1962 1974 1926 1904 1995 1969 1985 1963
#  1958 1892 2008 1971 1980 1945 1986 1981 1949 1940 1954 1925 1915 1921
#  1924 1999 1951 1993 1964 1900 1919 1910 1938 1880 1988 1911 1990 1979
#  1927 1983 1994 2009 1928 1917 1898 1997 1984 1973 1952 1939 1987 1890
#  1942 1991 1932 1908 1914 1882 1905 1875 1906 1893 1912 1913]
# YearRemodAdd [1976 1970 1997 1977 2000 2006 1996 1965 1950 2003 1960 1955 2007 2001
#  1961 1998 1953 2010 1995 2005 1992 1975 1978 1982 2002 1989 1967 1968
#  1959 2004 1966 2008 1987 1981 1969 1985 1963 1991 1993 1971 1990 1956
#  1986 1999 1954 1957 1994 1972 1958 1980 1979 1951 1983 2009 1962 1964
#  1952 1984 1988 1974 1973]
# ...

# %%
## Lets analyze the Temporal Datetime Variables
## We will check whether there is a relation between year the house is sold and the sales price
plt.figure(figsize=(8,8))
train.groupby('YrSold')['SalePrice'].median().plot()
plt.xlabel('Year Sold')
plt.ylabel('Median House Price')
plt.title("House Price vs YearSold")
# Out:
# Text(0.5, 1.0, 'House Price vs YearSold')

# %% [markdown]
# Clearly we can say house price decreases with increases with increases in the YearSold

# %%
## Here we will compare the difference between All years feature with SalePrice

for feature in year_feature:
    if feature!='YrSold':
        data=train.copy()
        ## We will capture the difference between year variable and year the house was sold for
        data[feature]=data['YrSold']-data[feature]

        plt.scatter(data[feature],data['SalePrice'])
        plt.xlabel(feature)
        plt.ylabel('SalePrice')
        plt.show()

# %% [markdown]
# When the house is new, initially prices are high, and with increase in the yearBuilt house price decreases.

# %%
## In our data we have two type of numerical values.  
## Conteneous and descrete values 

discrete_feature=[feature for feature in num_feature if len(train[feature].unique())<25 and feature not in year_feature]
print("Discrete Variables Count: {}".format(len(discrete_feature)))
# Out:
# Discrete Variables Count: 17

# %%
discrete_feature
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'LowQualFinSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold']

# %%
train[discrete_feature].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  LowQualFinSF  BsmtFullBath  \
# 0         120            6            5             0             0
# 1          20            8            6             0             1
# 2          60            7            5             0             1
# 3          20            6            6             0             0
# 4          20            6            7             0             0
#
#    BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  \
# 0             0         2         0             2             1             5
# 1             0         2         0             4             1             8
# 2             0         2         1             3             1             8
# 3             0         2         0             3             1             7
# 4             1         2         0             3             1             8
#
#    Fireplaces  GarageCars  3SsnPorch  PoolArea  MiscVal  MoSold
# ...

# %%
## Lets Find the realtionship between them and Sale PRice

for feature in discrete_feature:
    data=train.copy()
    plt.figure(figsize=(10,7))
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# With increase in the overall  materical and finish quality and Overall condition rating price of houses increase diractly
# Increase in number of full bath , Gargecar, fireplace,and  TotRmsAbvGrd price of house increases.

# %% [markdown]
# ### Continuous Variable

# %%
continuous_feature=[feature for feature in num_feature if feature not in discrete_feature+year_feature]
print("Continuous feature Count {}".format(len(continuous_feature)))
# Out:
# Continuous feature Count 17

# %%
continuous_feature
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'SalePrice']

# %%
## Lets analyse the continuous values by creating histograms to understand the distribution

for feature in continuous_feature:
    data=train.copy()
    plt.figure(figsize=(10,6))
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %% [markdown]
# Continuous_feature are not uniformaly distributed, data is right skewed.

# %% [markdown]
# ## Outliers

# %%
for feature in continuous_feature:
    data=train.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(column=feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()

# %% [markdown]
# All the continuous_feature having Outliers.

# %% [markdown]
# ### Categorical Variables

# %%
for feature in cat_feature:
    data=train.copy()
    plt.figure(figsize=(10,7))
    data.groupby(feature)['SalePrice'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('SalePrice')
    plt.title(feature)
    plt.show()

# %% [markdown]
# From  the graphs we can see the realtionship between price and categorical features, We can see a relation between all the columns.

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# In this section we will treat null values present in the train and test data.
# We will use encoding techniques to encode our categorical data and perform some scaling technique to reprent our data in same scale for better learnign of model.

# %%
train.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      NPkVill       Norm
# 1         Lvl    AllPub    Inside       Mod        NAmes       Norm
# 2         Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 3         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 4         Lvl    AllPub       FR2       Gtl       NWAmes       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
train.shape
# Out:
# (1168, 81)

# %%
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         HLS    AllPub    Corner       Gtl      StoneBr       Norm
# 1         Lvl    AllPub   CulDSac       Gtl      StoneBr       Norm
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Bnk    AllPub    Inside       Gtl      Crawfor       Norm
# 4         Lvl    AllPub   CulDSac       Gtl      Somerst      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test.shape
# Out:
# (292, 80)

# %% [markdown]
# ### Treating Null values

# %% [markdown]
# Here we can see our numerical feature is having Few null values in columns LotFrontage, MasVnrArea, and GarageYrBlt
#
# In categorical features we have many columns having null values.
# Alley,PoolQC,Fence, MiscFeature, and FireplaceQu are having null values more more than 50 percent, we will drop these coluns. for other null values we will fill them with median of that colums.
#
# In test data also we have almost complet missing data in the columns Alley, Fence and MiscFeature we will delete these columns.

# %% [markdown]
# In our numerical feature PoolQC is having maximum numbers of null values.
# LotFrontage, GarageYrBlt and MasVnrArea are having null values.
#
# Our Categorical column and numerical having more than 50 percent null values in columns Alley, PoolQC,FireplaceQu, Fence, MiscFeature
# we will drop these columns from our train and test data.

# %%
train.drop(['Id','Alley', 'PoolQC','FireplaceQu', 'Fence', 'MiscFeature'], axis=1 , inplace= True)

# %% [markdown]
# For numerical features we have null values present in LotFrontage , MasVnrArea , GarageYrBlt.
# For categoriacal feature we have null values present in MasVnrType, BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1, BsmtFinType2, GarageType, GarageFinish, GarageQual, GarageCond
#
# For numerical feature LotFrontage , MasVnrArea , GarageYrBlt we will fill the values using Meadian of that column.

# %%
train['LotFrontage'].fillna(value= train['LotFrontage'].median(), inplace= True)

train['MasVnrArea'].fillna(value= train['MasVnrArea'].median(), inplace= True)
train['GarageYrBlt'].fillna(value= train['GarageYrBlt'].median(), inplace= True)

# %% [markdown]
# For Categoical feature we will fill the nan values using Mode of the data.

# %%
train['MasVnrType'].fillna(value=train['MasVnrType'].mode()[0], inplace= True)
train['BsmtQual'].fillna(value=train['BsmtQual'].mode()[0], inplace= True)
train['BsmtCond'].fillna(value=train['BsmtCond'].mode()[0], inplace= True)
train['BsmtExposure'].fillna(value=train['BsmtExposure'].mode()[0], inplace= True)
train['BsmtFinType1'].fillna(value=train['BsmtFinType1'].mode()[0], inplace= True)
train['BsmtFinType2'].fillna(value=train['BsmtFinType2'].mode()[0], inplace= True)
train['GarageType'].fillna(value=train['GarageType'].mode()[0], inplace= True)
train['GarageFinish'].fillna(value=train['GarageFinish'].mode()[0], inplace= True)
train['GarageQual'].fillna(value=train['GarageQual'].mode()[0], inplace= True)
train['GarageCond'].fillna(value=train['GarageCond'].mode()[0], inplace= True)

# %%
train.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# ...

# %% [markdown]
# Now we have removed all the null values from the train set.
# Lets perform all same steps on test data.

# %%
test['LotFrontage'].fillna(value= test['LotFrontage'].median(), inplace= True)

test['MasVnrArea'].fillna(value= test['MasVnrArea'].median(), inplace= True)
test['GarageYrBlt'].fillna(value= test['GarageYrBlt'].median(), inplace= True)

# %%
test['MasVnrType'].fillna(value=test['MasVnrType'].mode()[0], inplace= True)
test['BsmtQual'].fillna(value=test['BsmtQual'].mode()[0], inplace= True)
test['BsmtCond'].fillna(value=test['BsmtCond'].mode()[0], inplace= True)
test['BsmtExposure'].fillna(value=test['BsmtExposure'].mode()[0], inplace= True)
test['BsmtFinType1'].fillna(value=test['BsmtFinType1'].mode()[0], inplace= True)
test['BsmtFinType2'].fillna(value=test['BsmtFinType2'].mode()[0], inplace= True)
test['GarageType'].fillna(value=test['GarageType'].mode()[0], inplace= True)
test['GarageFinish'].fillna(value=test['GarageFinish'].mode()[0], inplace= True)
test['GarageQual'].fillna(value=test['GarageQual'].mode()[0], inplace= True)
test['GarageCond'].fillna(value=test['GarageCond'].mode()[0], inplace= True)

# %%
test.drop(['Id','Alley', 'PoolQC','FireplaceQu', 'Fence', 'MiscFeature'], axis=1 , inplace= True)

# %%
test.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       1
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# ...

# %%
## Let's check the shape after removing the null values  
print(train.shape)
print(test.shape)
# Out:
# (1168, 75)
# (292, 74)

# %%
## Temporal Variables for train(Date Time Variables)

for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
       
    train[feature]=train['YrSold']-train[feature]

# %%
## Temporal Variables  for test (Date Time Variables)

for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
       
    test[feature]=test['YrSold']-test[feature]

# %%
train[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0         31            31         30.0
# 1         37            37         37.0
# 2         11            10         10.0
# 3         33            33         33.0
# 4         32             9         32.0

# %%
test[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          2             1          2.0
# 1         25            25         25.0
# 2          8             8          8.0
# 3         68            59         68.0
# 4          1             1          1.0

# %% [markdown]
# ### Numerical Variables

# %% [markdown]
# ### Since the numerical variables are skewed we will perform log normal distribution

# %%
import numpy as np
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea', 'SalePrice']

for feature in num_features:
    train[feature]=np.log(train[feature])

# %%
import numpy as np
num_features=['LotFrontage', 'LotArea', '1stFlrSF', 'GrLivArea']

for feature in num_features:
    test[feature]=np.log(test[feature])

# %% [markdown]
# ### Encoding Categorical Data

# %%
train.shape
# Out:
# (1168, 75)

# %%
test.shape
# Out:
# (292, 74)

# %%
train.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street LotShape LandContour  \
# 0         120       RL     4.248495  8.502689   Pave      IR1         Lvl
# 1          20       RL     4.553877  9.671871   Pave      IR1         Lvl
# 2          60       RL     4.521789  9.202308   Pave      IR1         Lvl
# 3          20       RL     4.653960  9.371694   Pave      IR1         Lvl
# 4          20       RL     4.248495  9.719264   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      NPkVill       Norm       Norm   TwnhsE
# 1    AllPub    Inside       Mod        NAmes       Norm       Norm     1Fam
# 2    AllPub   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl       NWAmes       Norm       Norm     1Fam
#
# ...

# %% [markdown]
# Let's divide the data into feature and target vector

# %%
train_feature=train.drop('SalePrice', axis=1)
train_target=train['SalePrice']

# %%
train_feature.head()
# Out:
#    MSSubClass MSZoning  LotFrontage   LotArea Street LotShape LandContour  \
# 0         120       RL     4.248495  8.502689   Pave      IR1         Lvl
# 1          20       RL     4.553877  9.671871   Pave      IR1         Lvl
# 2          60       RL     4.521789  9.202308   Pave      IR1         Lvl
# 3          20       RL     4.653960  9.371694   Pave      IR1         Lvl
# 4          20       RL     4.248495  9.719264   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      NPkVill       Norm       Norm   TwnhsE
# 1    AllPub    Inside       Mod        NAmes       Norm       Norm     1Fam
# 2    AllPub   CulDSac       Gtl      NoRidge       Norm       Norm     1Fam
# 3    AllPub    Inside       Gtl       NWAmes       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl       NWAmes       Norm       Norm     1Fam
#
# ...

# %%
train_target.head()
# Out:
# 0    11.759786
# 1    12.498742
# 2    12.505399
# 3    12.154779
# 4    12.278393
# Name: SalePrice, dtype: float64

# %%
data_new= pd.get_dummies(train_feature,sparse=False, drop_first=True )

# %%
data_new.shape
# Out:
# (1168, 229)

# %%
data_new['SalePrice']= train_target

# %% [markdown]
# ### Lets check Correlation

# %%
plt.figure(figsize=(20,60))
data_new.corr()['SalePrice'].sort_values(ascending=False).drop(['SalePrice']).plot(kind='barh',color='c')
plt.xlabel('Feature', fontsize=14)
plt.ylabel('Columns with target name', fontsize=14)
plt.title('Correlation',fontsize=18)
plt.grid(True)
plt.show()

# %% [markdown]
# Here we can see the feature on the right of 0.0 are having positive correlation and features on the left of 0.0 are negatively correlated.

# %% [markdown]
# ### Scaling the data Using StandardScaler.

# %%
# Dividing into Feature andx Target data
x=data_new.drop(['SalePrice'],axis=1)
y=data_new['SalePrice']

# %%
from sklearn.preprocessing import StandardScaler
SDC=StandardScaler()
x=SDC.fit_transform(x)

# %%
dfx= pd.DataFrame(data= x, columns= data_new.columns[0:229])

# %%
dfx.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    1.508301     0.112026 -1.217608    -0.075169    -0.530217  -0.194636
# 1   -0.877042     1.082895  1.097402     1.364138     0.359572   0.004170
# 2    0.077095     0.980880  0.167657     0.644484    -0.530217  -0.857322
# 3   -0.877042     1.401081  0.503044    -0.075169     0.359572  -0.128367
# 4   -0.877042     0.112026  1.191243    -0.075169     1.249361  -0.161501
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0      0.382860   -0.558343   -0.702161   -0.285392   0.864410     0.038239
# 1      0.671675   -0.558343   -0.202665    4.749787   1.053642     2.614679
# 2     -0.627990   -0.558343    0.902279   -0.285392  -0.700654     0.126458
# 3      0.479132    2.076985    0.562795   -0.285392   1.267363     1.770946
# 4     -0.676126    0.133430    1.732609   -0.285392  -0.475801     1.223537
#
# ...

# %% [markdown]
# ## Perform Same steps On test data

# %%
data_test= pd.get_dummies(test,sparse=False, drop_first=True )

# %%
data_test.shape
# Out:
# (292, 200)

# %%
data_testy=SDC.fit_transform(data_test)

# %%
data_testy=pd.DataFrame(data=data_testy, columns=data_test.columns)

# %%
dfx.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    1.508301     0.112026 -1.217608    -0.075169    -0.530217  -0.194636
# 1   -0.877042     1.082895  1.097402     1.364138     0.359572   0.004170
# 2    0.077095     0.980880  0.167657     0.644484    -0.530217  -0.857322
# 3   -0.877042     1.401081  0.503044    -0.075169     0.359572  -0.128367
# 4   -0.877042     0.112026  1.191243    -0.075169     1.249361  -0.161501
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0      0.382860   -0.558343   -0.702161   -0.285392   0.864410     0.038239
# 1      0.671675   -0.558343   -0.202665    4.749787   1.053642     2.614679
# 2     -0.627990   -0.558343    0.902279   -0.285392  -0.700654     0.126458
# 3      0.479132    2.076985    0.562795   -0.285392   1.267363     1.770946
# 4     -0.676126    0.133430    1.732609   -0.285392  -0.475801     1.223537
#
# ...

# %%
data_testy.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   -0.856054     0.926381  0.842901     2.157766    -0.464603  -1.092014
# 1    1.431981     0.096736 -0.738620     1.419117    -0.464603  -0.336480
# 2   -0.856054     0.096736  0.524986     1.419117    -0.464603  -0.894918
# 3    0.287963     0.520807  0.549140     0.680468     1.419621   1.076040
# 4    0.059160     0.926381  0.897415    -0.058181    -0.464603  -1.124864
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0     -1.075294    0.522510    1.888202   -0.303257   0.281925     2.074477
# 1      0.121412   -0.623319    1.391494   -0.303257  -0.909772     0.418166
# 2     -0.726255   -0.623319   -1.024418   -0.303257   2.913893     1.675735
# 3      1.816747   -0.623319   -0.383129   -0.303257  -0.312705    -0.799293
# 4     -1.075294   -0.199362   -1.024418   -0.303257   0.820504    -0.351004
#
# ...

# %% [markdown]
# #### Making all the data columns equal for both test and train

# %%
data_testy1=['Utilities_NoSeWa', 'Exterior1st_CBlock','Exterior2nd_CBlock']

# %%
list=['MSZoning_RH', 'Neighborhood_Blueste','Condition1_RRNe' ,'Condition2_Feedr','Condition2_Norm','Condition2_PosA','Condition2_PosN','Condition2_RRAe','Condition2_RRAn', 'RoofStyle_Shed','RoofMatl_CompShg','RoofMatl_Membran','RoofMatl_Metal','RoofMatl_Roll','RoofMatl_WdShngl','Exterior1st_AsphShn','Exterior1st_ImStucc', 'Exterior1st_Stone', 'Exterior2nd_AsphShn','Exterior2nd_Other','ExterCond_Po', 'BsmtCond_Po', 'Heating_GasA','Heating_Wall', 'HeatingQC_Po','Electrical_Mix','Functional_Sev','SaleType_Con','SaleType_ConLI','SaleType_Oth','SaleCondition_AdjLand','SaleCondition_Alloca']

# %%
len(list)
# Out:
# 32

# %%
data_testy.shape
# Out:
# (292, 200)

# %%
dfx.shape
# Out:
# (1168, 229)

# %%
len(list)
# Out:
# 32

# %%
dfx.drop(list, axis=1, inplace= True)

# %%
data_testy.drop(data_testy1, axis=1, inplace = True)

# %%
data_testy.shape
# Out:
# (292, 197)

# %%
dfx.shape
# Out:
# (1168, 197)

# %% [markdown]
# ### VIF Calculation

# %%
import statsmodels.api as sm
from scipy import stats
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif['variables']=x.columns
    vif['VIF FACTOR']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.520492
# 1              LotFrontage    3.419958
# 2                  LotArea    5.115955
# 3              OverallQual    5.663367
# 4              OverallCond    2.656151
# 5                YearBuilt   14.319586
# 6             YearRemodAdd    3.673709
# 7               MasVnrArea    2.911349
# 8               BsmtFinSF1         inf
# 9               BsmtFinSF2         inf
# 10               BsmtUnfSF         inf
# 11             TotalBsmtSF         inf
# 12                1stFlrSF   28.886016
# 13                2ndFlrSF   27.266375
# 14            LowQualFinSF    2.495198
# 15               GrLivArea   44.275924
# 16            BsmtFullBath    2.887497
# 17            BsmtHalfBath    1.483722
# 18                FullBath    4.148007
# 19                HalfBath    3.135840
# 20            BedroomAbvGr    3.620336
# 21            KitchenAbvGr    4.212782
# 22            TotRmsAbvGrd    6.480905
# ...

# %%
dfx.drop('BsmtFinSF1', axis=1, inplace= True)
data_testy.drop('BsmtFinSF1', axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.520492
# 1              LotFrontage    3.419958
# 2                  LotArea    5.115955
# 3              OverallQual    5.663367
# 4              OverallCond    2.656151
# 5                YearBuilt   14.319586
# 6             YearRemodAdd    3.673709
# 7               MasVnrArea    2.911349
# 8               BsmtFinSF2    4.266782
# 9                BsmtUnfSF    4.734183
# 10             TotalBsmtSF    7.716903
# 11                1stFlrSF   28.886016
# 12                2ndFlrSF   27.266375
# 13            LowQualFinSF    2.495198
# 14               GrLivArea   44.275924
# 15            BsmtFullBath    2.887497
# 16            BsmtHalfBath    1.483722
# 17                FullBath    4.148007
# 18                HalfBath    3.135840
# 19            BedroomAbvGr    3.620336
# 20            KitchenAbvGr    4.212782
# 21            TotRmsAbvGrd    6.480905
# 22              Fireplaces    2.107932
# ...

# %%
dfx.drop('GarageCond_TA', axis=1, inplace= True)
data_testy.drop('GarageCond_TA', axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.508768
# 1              LotFrontage    3.419219
# 2                  LotArea    5.109369
# 3              OverallQual    5.652378
# 4              OverallCond    2.654779
# 5                YearBuilt   14.309950
# 6             YearRemodAdd    3.669520
# 7               MasVnrArea    2.911349
# 8               BsmtFinSF2    4.263664
# 9                BsmtUnfSF    4.734180
# 10             TotalBsmtSF    7.711327
# 11                1stFlrSF   28.878426
# 12                2ndFlrSF   27.131146
# 13            LowQualFinSF    2.441528
# 14               GrLivArea   44.258143
# 15            BsmtFullBath    2.883124
# 16            BsmtHalfBath    1.482673
# 17                FullBath    4.146712
# 18                HalfBath    3.134540
# 19            BedroomAbvGr    3.605930
# 20            KitchenAbvGr    4.210521
# 21            TotRmsAbvGrd    6.468398
# 22              Fireplaces    2.106202
# ...

# %%
dfx.drop('GarageType_Attchd', axis=1, inplace= True)
data_testy.drop('GarageType_Attchd', axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.446919
# 1              LotFrontage    3.417875
# 2                  LotArea    5.108381
# 3              OverallQual    5.650030
# 4              OverallCond    2.654709
# 5                YearBuilt   14.307861
# 6             YearRemodAdd    3.668731
# 7               MasVnrArea    2.906421
# 8               BsmtFinSF2    4.259951
# 9                BsmtUnfSF    4.726444
# 10             TotalBsmtSF    7.709487
# 11                1stFlrSF   28.851211
# 12                2ndFlrSF   27.130346
# 13            LowQualFinSF    2.439215
# 14               GrLivArea   44.258138
# 15            BsmtFullBath    2.882974
# 16            BsmtHalfBath    1.479500
# 17                FullBath    4.138955
# 18                HalfBath    3.130092
# 19            BedroomAbvGr    3.592350
# 20            KitchenAbvGr    4.205287
# 21            TotRmsAbvGrd    6.460799
# 22              Fireplaces    2.105933
# ...

# %%
dfx.drop('SaleType_New', axis=1, inplace= True)
data_testy.drop('SaleType_New', axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.367518
# 1              LotFrontage    3.413836
# 2                  LotArea    5.107651
# 3              OverallQual    5.649740
# 4              OverallCond    2.640684
# 5                YearBuilt   14.258195
# 6             YearRemodAdd    3.668220
# 7               MasVnrArea    2.906314
# 8               BsmtFinSF2    4.257777
# 9                BsmtUnfSF    4.725971
# 10             TotalBsmtSF    7.708903
# 11                1stFlrSF   28.820395
# 12                2ndFlrSF   27.129817
# 13            LowQualFinSF    2.438843
# 14               GrLivArea   44.249807
# 15            BsmtFullBath    2.871941
# 16            BsmtHalfBath    1.477846
# 17                FullBath    4.138930
# 18                HalfBath    3.129455
# 19            BedroomAbvGr    3.591168
# 20            KitchenAbvGr    4.200717
# 21            TotRmsAbvGrd    6.460799
# 22              Fireplaces    2.105534
# ...

# %%
dfx.drop(['GarageQual_TA'], axis=1, inplace= True)
data_testy.drop(['GarageQual_TA'], axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.360378
# 1              LotFrontage    3.412544
# 2                  LotArea    5.106407
# 3              OverallQual    5.590544
# 4              OverallCond    2.638903
# 5                YearBuilt   14.198994
# 6             YearRemodAdd    3.665661
# 7               MasVnrArea    2.901632
# 8               BsmtFinSF2    4.247778
# 9                BsmtUnfSF    4.725005
# 10             TotalBsmtSF    7.708901
# 11                1stFlrSF   28.698804
# 12                2ndFlrSF   26.741419
# 13            LowQualFinSF    2.382825
# 14               GrLivArea   43.736723
# 15            BsmtFullBath    2.867084
# 16            BsmtHalfBath    1.475643
# 17                FullBath    4.135382
# 18                HalfBath    3.120380
# 19            BedroomAbvGr    3.591029
# 20            KitchenAbvGr    4.200397
# 21            TotRmsAbvGrd    6.458878
# 22              Fireplaces    2.100161
# ...

# %%
dfx.drop(['RoofStyle_Gable'], axis=1, inplace= True)
data_testy.drop(['RoofStyle_Gable'], axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.277217
# 1              LotFrontage    3.412060
# 2                  LotArea    5.106401
# 3              OverallQual    5.562112
# 4              OverallCond    2.638538
# 5                YearBuilt   14.197297
# 6             YearRemodAdd    3.663044
# 7               MasVnrArea    2.896241
# 8               BsmtFinSF2    4.193002
# 9                BsmtUnfSF    4.720603
# 10             TotalBsmtSF    7.708179
# 11                1stFlrSF   28.697102
# 12                2ndFlrSF   26.730578
# 13            LowQualFinSF    2.382657
# 14               GrLivArea   43.722570
# 15            BsmtFullBath    2.861703
# 16            BsmtHalfBath    1.461676
# 17                FullBath    4.130681
# 18                HalfBath    3.120338
# 19            BedroomAbvGr    3.569548
# 20            KitchenAbvGr    4.200397
# 21            TotRmsAbvGrd    6.456421
# 22              Fireplaces    2.098665
# ...

# %%
dfx.drop(['Exterior2nd_MetalSd'], axis=1, inplace= True)
data_testy.drop(['Exterior2nd_MetalSd'], axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.273200
# 1              LotFrontage    3.411720
# 2                  LotArea    5.096307
# 3              OverallQual    5.561989
# 4              OverallCond    2.637952
# 5                YearBuilt   14.191417
# 6             YearRemodAdd    3.662409
# 7               MasVnrArea    2.895634
# 8               BsmtFinSF2    4.191504
# 9                BsmtUnfSF    4.716121
# 10             TotalBsmtSF    7.707543
# 11                1stFlrSF   28.567398
# 12                2ndFlrSF   26.707784
# 13            LowQualFinSF    2.382216
# 14               GrLivArea   43.655341
# 15            BsmtFullBath    2.857672
# 16            BsmtHalfBath    1.452319
# 17                FullBath    4.130293
# 18                HalfBath    3.117723
# 19            BedroomAbvGr    3.567984
# 20            KitchenAbvGr    4.199390
# 21            TotRmsAbvGrd    6.456409
# 22              Fireplaces    2.098317
# ...

# %%
dfx.drop(['Exterior2nd_CmentBd'], axis=1, inplace= True)
data_testy.drop(['Exterior2nd_CmentBd'], axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.218938
# 1              LotFrontage    3.408659
# 2                  LotArea    5.077179
# 3              OverallQual    5.557771
# 4              OverallCond    2.637795
# 5                YearBuilt   14.190483
# 6             YearRemodAdd    3.661959
# 7               MasVnrArea    2.892052
# 8               BsmtFinSF2    4.187031
# 9                BsmtUnfSF    4.704893
# 10             TotalBsmtSF    7.705550
# 11                1stFlrSF   28.564130
# 12                2ndFlrSF   26.707566
# 13            LowQualFinSF    2.382175
# 14               GrLivArea   43.636330
# 15            BsmtFullBath    2.856507
# 16            BsmtHalfBath    1.452144
# 17                FullBath    4.129106
# 18                HalfBath    3.113802
# 19            BedroomAbvGr    3.564840
# 20            KitchenAbvGr    4.199295
# 21            TotRmsAbvGrd    6.427972
# 22              Fireplaces    2.095180
# ...

# %%
dfx.drop(['MasVnrType_None'], axis=1, inplace= True)
data_testy.drop(['MasVnrType_None'], axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.209735
# 1              LotFrontage    3.408656
# 2                  LotArea    5.076790
# 3              OverallQual    5.555809
# 4              OverallCond    2.636609
# 5                YearBuilt   14.165640
# 6             YearRemodAdd    3.650262
# 7               MasVnrArea    2.781469
# 8               BsmtFinSF2    4.175740
# 9                BsmtUnfSF    4.692241
# 10             TotalBsmtSF    7.663032
# 11                1stFlrSF   28.555115
# 12                2ndFlrSF   26.701582
# 13            LowQualFinSF    2.381833
# 14               GrLivArea   43.636243
# 15            BsmtFullBath    2.847014
# 16            BsmtHalfBath    1.447356
# 17                FullBath    4.128620
# 18                HalfBath    3.113481
# 19            BedroomAbvGr    3.564750
# 20            KitchenAbvGr    4.194982
# 21            TotRmsAbvGrd    6.426734
# 22              Fireplaces    2.093602
# ...

# %%
dfx.drop(['ExterQual_TA'], axis=1, inplace= True)
data_testy.drop(['ExterQual_TA'], axis=1, inplace= True)

# %%
calc_vif(dfx)
# Out:
#                  variables  VIF FACTOR
# 0               MSSubClass   29.175218
# 1              LotFrontage    3.408238
# 2                  LotArea    5.076282
# 3              OverallQual    5.430925
# 4              OverallCond    2.627220
# 5                YearBuilt   14.161601
# 6             YearRemodAdd    3.649150
# 7               MasVnrArea    2.753456
# 8               BsmtFinSF2    4.175288
# 9                BsmtUnfSF    4.684658
# 10             TotalBsmtSF    7.634862
# 11                1stFlrSF   28.528361
# 12                2ndFlrSF   26.673155
# 13            LowQualFinSF    2.381573
# 14               GrLivArea   43.625308
# 15            BsmtFullBath    2.846237
# 16            BsmtHalfBath    1.447212
# 17                FullBath    4.115231
# 18                HalfBath    3.110197
# 19            BedroomAbvGr    3.563565
# 20            KitchenAbvGr    4.193712
# 21            TotRmsAbvGrd    6.401420
# 22              Fireplaces    2.093480
# ...

# %% [markdown]
# We can see our VIF is less than 20 we can proceed with model dev.

# %%
dfx.shape
# Out:
# (1168, 187)

# %%
data_testy.shape
# Out:
# (292, 187)

# %%
dfx.head()
# Out:
#    MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  YearBuilt  \
# 0    1.508301     0.112026 -1.217608    -0.075169    -0.530217  -0.194636
# 1   -0.877042     1.082895  1.097402     1.364138     0.359572   0.004170
# 2    0.077095     0.980880  0.167657     0.644484    -0.530217  -0.857322
# 3   -0.877042     1.401081  0.503044    -0.075169     0.359572  -0.128367
# 4   -0.877042     0.112026  1.191243    -0.075169     1.249361  -0.161501
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0      0.382860   -0.558343   -0.285392   0.864410     0.038239 -0.470361
# 1      0.671675   -0.558343    4.749787   1.053642     2.614679  2.179040
# 2     -0.627990   -0.558343   -0.285392  -0.700654     0.126458  0.042640
# 3      0.479132    2.076985   -0.285392   1.267363     1.770946  1.597359
# 4     -0.676126    0.133430   -0.285392  -0.475801     1.223537  1.153138
#
# ...

# %%
y.shape
# Out:
# (1168,)

# %%
x=dfx

# %%
x.shape
# Out:
# (1168, 187)

# %% [markdown]
# ### Model Design

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.neighbors import KNeighborsRegressor

from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor


from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %% [markdown]
# #### 1.Linear Regression

# %%
lr=LinearRegression()
for i in range(0, 100):
    x_train, x_test, y_train, y_test= train_test_split(x,y,random_state= i,test_size=0.25)
    lr.fit(x_train,y_train)
    pred_train= lr.predict(x_train)
    pred_test= lr.predict(x_test)
    print(f"At Random Stat {i}, the training accuracy is:{r2_score(y_train,pred_train)}")
    print(f"At Random Stat {i}, the testing accuracy is:{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At Random Stat 0, the training accuracy is:0.9370783284327837
# At Random Stat 0, the testing accuracy is:0.5654951310712972
#
#
# At Random Stat 1, the training accuracy is:0.9334331377016594
# At Random Stat 1, the testing accuracy is:-1.3222556400398142e+25
#
#
# At Random Stat 2, the training accuracy is:0.9333323589212376
# At Random Stat 2, the testing accuracy is:0.8674831260474563
#
#
# At Random Stat 3, the training accuracy is:0.9312071587442736
# At Random Stat 3, the testing accuracy is:-6.2465639657188525
#
#
# At Random Stat 4, the training accuracy is:0.9383427968954454
# At Random Stat 4, the testing accuracy is:-3.7429562514590383e+24
#
#
# At Random Stat 5, the training accuracy is:0.9477322282297587
# At Random Stat 5, the testing accuracy is:0.4954443267682812
#
#
# At Random Stat 6, the training accuracy is:0.9283366117134851
# At Random Stat 6, the testing accuracy is:0.8965495567661635
#
#
# At Random Stat 7, the training accuracy is:0.9325386453087074
# ...

# %% [markdown]
# At Random Stat 99, the training accuracy is:0.9300250239079275 and the testing accuracy is:0.8902707030534185
# Both are nearly same , we can select it as best random state.

# %%
x_train_b, x_test_b, y_train_b, y_test_b= train_test_split(x,y,random_state=99,test_size=0.25)

# %%
lr.fit(x_train_b, y_train_b)
lr_pred=lr.predict(x_test_b)
print(r2_score(y_test_b,lr_pred))
# Out:
# 0.8902707030534185

# %% [markdown]
# ### Cross Validation of Model

# %%
test_accuracy= r2_score(y_test_b,lr_pred)

from sklearn.model_selection import cross_val_score
for i in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=i)
    cv_mean=cv_score.mean()
    print(f"At cross fold {i} the Cross Val score is {cv_mean*100} and Accuracy score is {test_accuracy*100}")
# Out:
# At cross fold 2 the Cross Val score is -7.870011817580494e+25 and Accuracy score is 89.02707030534185
# At cross fold 3 the Cross Val score is -7.561103731177972e+25 and Accuracy score is 89.02707030534185
# At cross fold 4 the Cross Val score is -1.568139729310082e+26 and Accuracy score is 89.02707030534185
# At cross fold 5 the Cross Val score is -1.081419751367906e+25 and Accuracy score is 89.02707030534185
# At cross fold 6 the Cross Val score is -9.493627539462243e+21 and Accuracy score is 89.02707030534185
# At cross fold 7 the Cross Val score is -4.508852167012427e+26 and Accuracy score is 89.02707030534185
# At cross fold 8 the Cross Val score is -5.409618607743941e+25 and Accuracy score is 89.02707030534185
# At cross fold 9 the Cross Val score is -6.555051936278212e+24 and Accuracy score is 89.02707030534185

# %% [markdown]
# Model performance is very poor lets try another model.

# %% [markdown]
# ### 2. Lasso

# %%
ls=Lasso()
ls.fit(x_train_b, y_train_b)
ls.score(x_train_b, y_train_b)
ls_pred=ls.predict(x_test_b)

lsd=r2_score(y_test_b, ls_pred)
print('R2 score:', lsd*100)

rdscore= cross_val_score(ls,x,y,cv=4,scoring='r2')
lsc=rdscore.mean()
print('Cross val Score :', lsc*100)
# Out:
# R2 score: -0.2006096383677436
# Cross val Score : -1.1486715530197311

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,ls_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,ls_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,ls_pred)))
# Out:
# Error:
# Mean Absolute Error: 0.3112817022057695
# Mean Squared Error: 0.17100936271636324
# Root Mean Square Error: 0.413532783121681

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= ls_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual Price', fontsize= 14 )
plt.ylabel('predicted Price', fontsize= 18)
plt.show()

# %% [markdown]
# ### R2 score and Cross val score both are very less, Lasso also not performing well.

# %% [markdown]
# ### 3. Ridge

# %%
rd= Ridge()
rd.fit(x_train_b, y_train_b)
rd.score(x_train_b, y_train_b)
rd_pred= rd.predict(x_test_b)

rds=r2_score(y_test_b, rd_pred)
print('r2 score: ', rds*100)

rdcvscore= cross_val_score(rd,x,y,cv=4, scoring='r2')
rdcv=rdcvscore.mean()
print('Cross val Score', rdcv*100)
# Out:
# r2 score:  89.03116770831119
# Cross val Score 85.79184971693921

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,rd_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,rd_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,rd_pred)))
# Out:
# Error:
# Mean Absolute Error: 0.09582587602841704
# Mean Squared Error: 0.01872017572262473
# Root Mean Square Error: 0.13682169317262788

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= rd_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# Ridge performance is very good as compare to other model. we canconsider it as best model.

# %% [markdown]
# ### 4. KNeighborsRegressor

# %%
kn=KNeighborsRegressor()
kn.fit(x_train_b, y_train_b)
kn.score(x_train_b,y_train_b)
kn_pred=kn.predict(x_test_b)

kn_score= r2_score(y_test_b, kn_pred)
print('R2 Score:', kn_score*100)

kn_cvscore=cross_val_score(kn,x,y, cv=4, scoring='r2')
cv_mean=kn_cvscore.mean()
print('Cross val Score :',cv_mean*100 )
# Out:
# R2 Score: 77.09579006192048
# Cross val Score : 71.94486355856714

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,kn_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,kn_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,kn_pred)))
# Out:
# Error:
# Mean Absolute Error: 0.14299844440162973
# Mean Squared Error: 0.039089925292560085
# Root Mean Square Error: 0.1977117226988832

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= kn_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# R2 Score: 77.09579006192048 and Cross val Score : 71.94486355856714,
# Big diffrence in score , Ridge is still our best model

# %% [markdown]
# ### 5. Ensemble Techniques

# %%
rf=RandomForestRegressor()
rf.fit(x_train_b, y_train_b)
rf.score(x_train_b,y_train_b)
rf_pred=rf.predict(x_test_b)

rf_score= r2_score(y_test_b, rf_pred)
print('R2 score:', rf_score*100)

rfcv=cross_val_score(rf,x,y, cv=4, scoring='r2')
rfcvscore=rfcv.mean()
print('Cross val Score :',rfcvscore*100 )
# Out:
# R2 score: 86.9564988872136
# Cross val Score : 85.17093833463211

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,rf_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,rf_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,rf_pred)))
# Out:
# Error:
# Mean Absolute Error: 0.10033964075628916
# Mean Squared Error: 0.022260950516549294
# Root Mean Square Error: 0.1492010406014291

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= rf_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# R2 score: 86.9564988872136 and Cross val Score : 85.17093833463211
# Errors are less an diffrence in score also very less as compare to other model, RandomForestRegressor workign well.

# %% [markdown]
# ### 7. GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gb=GradientBoostingRegressor()
gb.fit(x_train_b, y_train_b)
gb.score(x_train_b,y_train_b)
gb_pred=rf.predict(x_test_b)

gb_score= r2_score(y_test_b, gb_pred)
print('R2 score:', gb_score*100)

gbcv=cross_val_score(gb,x,y, cv=4, scoring='r2')
gbcvscore=gbcv.mean()
print('Cross val Score :',gbcvscore*100 )
# Out:
# R2 score: 86.9564988872136
# Cross val Score : 86.54269556646722

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,gb_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,gb_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,gb_pred)))
# Out:
# Error:
# Mean Absolute Error: 0.10033964075628916
# Mean Squared Error: 0.022260950516549294
# Root Mean Square Error: 0.1492010406014291

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= gb_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %% [markdown]
# R2 score: 86.9564988872136 and Cross val Score : 86.54269556646722
# Both the Score and error are less Model performance is very good.

# %% [markdown]
# ### Lets Try Hyper Parameter Tuning

# %% [markdown]
# We try Hyper parametre Tuning on Ridge, GradientBoostingRegressor,RandomForestRegressor and find out best model

# %%
# Hyper Parameter tuning on  Ridge
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Ridge
parameters= {'alpha':[0.0001,0.001,0.01,0.1,1,10], 'fit_intercept': [True,False], 'normalize':[True, False], 'copy_X': [True , False], 'tol':[0.0001,0.001,0.01,0.1,1,10]}
rd=Ridge()
rdclf=GridSearchCV(rd, parameters)
rdclf.fit(x_train_b, y_train_b)
print(rdclf.best_params_)
# Out:
# {'alpha': 10, 'copy_X': True, 'fit_intercept': True, 'normalize': False, 'tol': 0.0001}

# %%
rd= Ridge(alpha= 10, copy_X= True, fit_intercept= True, normalize= False, tol= 0.0001)
rd.fit(x_train_b, y_train_b)
rd.score(x_train_b, y_train_b)
rd_pred= rd.predict(x_test_b)

rds=r2_score(y_test_b, rd_pred)
print('r2 score: ', rds*100)

rdcvscore= cross_val_score(rd,x,y,cv=4, scoring='r2')
rdcv=rdcvscore.mean()
print('Cross val Score', rdcv*100)
# Out:
# r2 score:  89.04076642821846
# Cross val Score 86.31748625467847

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,rd_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,rd_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,rd_pred)))
# Out:
# Error:
# Mean Absolute Error: 0.0949855520751652
# Mean Squared Error: 0.018703793876444764
# Root Mean Square Error: 0.136761814394387

# %% [markdown]
# Accuracy improved but still not considerable, lets try on other models.

# %%
from sklearn.model_selection import GridSearchCV
parameters={'criterion':['mse', 'mae'],'max_features':['auto', 'sqrt', 'log2'],'n_estimators':[10,20,30,70, 100], 'min_samples_split':[1,2,3,4,10]}
rf=RandomForestRegressor()
rfclf=GridSearchCV(rf, param_grid=parameters, n_jobs=-1)
rfclf.fit(x_train_b, y_train_b)
print(rfclf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto', 'min_samples_split': 3, 'n_estimators': 100}

# %%
rf=RandomForestRegressor(criterion='mse', max_features='auto', min_samples_split=3, n_estimators=100)
rf.fit(x_train_b, y_train_b)
rf.score(x_train_b,y_train_b)
rf_pred=rf.predict(x_test_b)

rf_score= r2_score(y_test_b, rf_pred)
print('R2 score:', rf_score*100)

rfcv=cross_val_score(rf,x,y, cv=4, scoring='r2')
rfcvscore=rfcv.mean()
print('Cross val Score :',rfcvscore*100 )
# Out:
# R2 score: 86.42669356434254
# Cross val Score : 84.48672302381908

# %%
print('Error:')

print('Mean Absolute Error:',mean_absolute_error(y_test_b,rf_pred))
print('Mean Squared Error:', mean_squared_error(y_test_b,rf_pred))
print('Root Mean Square Error:', np.sqrt(mean_squared_error(y_test_b,rf_pred)))
# Out:
# Error:
# Mean Absolute Error: 0.10129789731454189
# Mean Squared Error: 0.023165153304884663
# Root Mean Square Error: 0.15220102925041165

# %%
plt.figure(figsize=(8,7))
plt.scatter(x=y_test_b, y= rf_pred, color='r')
plt.plot(y_test_b,y_test_b, color='b')
plt.xlabel('Actual sale', fontsize= 14 )
plt.ylabel('predicted sale', fontsize= 18)
plt.show()

# %%
R2 score: 86.42669356434254 and Cross val Score : 84.48672302381908 
Both the score having diffrence Model performance is not good

# %%
from sklearn.ensemble import GradientBoostingRegressor
parameters={'loss':['lad', 'huber'],'criterion':['friedman_mse', 'mae'], 'learning_rate':[0.001,0.01,0.1], 'n_estimators':[10,20,100]}
gb=GradientBoostingRegressor()
gbclf=GridSearchCV(gb, param_grid=parameters, n_jobs=-1)
gbclf.fit(x_train_b, y_train_b)
print(gbclf.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'learning_rate': 0.1, 'loss': 'huber', 'n_estimators': 100}

# %%
gb=GradientBoostingRegressor(criterion='friedman_mse',learning_rate=0.1, loss='huber', n_estimators= 100)
gb.fit(x_train_b, y_train_b)
gb.score(x_train_b,y_train_b)
gb_pred=rf.predict(x_test_b)

gb_score= r2_score(y_test_b, rf_pred)
print('R2 score:', gb_score*100)

gbcv=cross_val_score(gb,x,y, cv=4, scoring='r2')
gbcvscore=gbcv.mean()
print('Cross val Score :',gbcvscore*100 )
# Out:
# R2 score: 86.42669356434254
# Cross val Score : 86.81559033182664

# %% [markdown]
# R2 score: 86.42669356434254 and Cross val Score : 86.81559033182664
# GradientBoostingRegressor  is out best model. Lets save this model.

# %%
import pickle
filename='HOUSING_PRICE_PREDICTION_new.pkl'
pickle.dump(rf,open(filename,'wb'))

# %%
import numpy as np
a=np.array(y_test_b)
predicted= np.array(rf.predict(x_test_b))
df_com= pd.DataFrame({'original':a, 'predicted':predicted}, index= range(len(a)))
df_com
# Out:
#       original  predicted
# 0    10.596635  11.560344
# 1    12.560244  12.604795
# 2    12.154779  12.279185
# 3    12.075394  12.094784
# 4    11.982617  11.949292
# 5    12.043554  11.989885
# 6    12.072541  12.100722
# 7    12.141534  12.113487
# 8    12.138864  12.117087
# 9    12.363076  12.382276
# 10   11.732061  11.668512
# 11   11.798104  12.004297
# 12   12.793859  12.732621
# 13   11.018629  11.139304
# 14   11.751942  11.644674
# 15   12.880292  12.523799
# 16   11.808948  11.890475
# 17   12.109011  12.029876
# 18   11.792449  11.812364
# 19   11.938193  11.836258
# 20   12.936752  12.851288
# 21   12.128111  12.219909
# 22   11.685685  11.771093
# 23   12.305918  12.280578
# 24   11.794338  11.807644
# 25   11.804849  12.102958
# 26   11.512925  11.423614
# 27   11.745425  11.785074
# 28   12.128111  12.080479
# 29   12.312682  12.313174
# 30   11.728037  11.783717
# 31   12.154516  12.052932
# 32   11.931636  11.899169
# 33   11.338572  11.301194
# ...

# %%
loaded_model = pickle.load(open(filename,'rb'))

# %%
prediction=loaded_model.predict(data_testy)

# %%
print(prediction)
# Out:
# [12.75850922 12.24830276 12.33353697 12.03353544 12.19626369 11.32273702
#  11.84165123 12.57007    12.43148445 11.98465019 11.23064383 11.90838897
#  11.73191463 12.06788492 12.63388741 11.70988344 11.67458067 11.7449164
#  12.05894308 12.23670188 11.98732107 11.86829012 11.92758315 11.38880332
#  11.50327852 11.7386481  12.09243205 11.86653211 12.04357894 11.57912538
#  11.91943815 12.18236195 12.34556569 11.99605324 11.62993358 12.06808729
#  12.1277329  11.64627093 12.00896606 11.91998985 11.4869376  12.68920741
#  12.22560783 12.16514751 11.79473459 11.79010824 11.77103643 11.5315998
#  12.24716211 12.68922133 11.86980288 12.12219926 11.5786966  11.52289366
#  12.57776769 11.7273483  11.88423695 12.1452706  11.68496847 12.43372742
#  11.4049488  12.00692404 11.77351178 11.84622709 12.21232218 11.41090456
#  11.93642949 12.25527568 11.82320018 11.99423952 12.58808839 12.03419936
#  12.08925482 11.93570184 11.83870257 12.44472582 12.61551584 12.17827949
# ...

# %%
predicted= pd.DataFrame(data=prediction)

predicted.to_csv('prediction.csv',index=False)
